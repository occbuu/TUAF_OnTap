# %% [markdown]
# Lưu ý:
#  - D : Độc chất học thú y
#  - E : Dinh dưỡng động vật
#  - F : Giải phẫu động vật

# %%
s = 'python -X utf8 combine_quiz.py -s "Giải phẫu động vật" '
for i in range(1, 13):
    xx = f'{i:02d}'
    s += f'LT_F{xx}.html '
print(s)
# Out:
# python -X utf8 combine_quiz.py -s "Giải phẫu động vật" LT_F01.html LT_F02.html LT_F03.html LT_F04.html LT_F05.html LT_F06.html LT_F07.html LT_F08.html LT_F09.html LT_F10.html LT_F11.html LT_F12.html

# %%
s = 'python -X utf8 combine_quiz.py '
for i in range(1, 7):
    xx = f'{i:02d}'
    s += f'LT_D{xx}.html '
print(s)
# Out:
# python -X utf8 combine_quiz.py LT_D01.html LT_D02.html LT_D03.html LT_D04.html LT_D05.html LT_D06.html
